# %%
from astropy.io import fits

# %%
hdul = fits.open("clump.FIT")

# %%
hdul.info()
# Out:
# Filename: clump.FIT
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       6   ()
#   1  clump         1 BinTableHDU    485   95R x 10C   [J, D, D, D, D, D, D, D, D, D]

# %%
hdul[1].data
# Out:
# FITS_rec([( 1, 127.09886637, 25.37418126, 127.09929987, 25.3748715 ,  1.61877423,  3.72701644, 456.27386636, 122.16888183,  351.9978564 ),
#           ( 2, 127.2550663 , 25.40305382, 127.25590398, 25.40388504,  5.91228611,  5.88467863, 222.72938568,  27.65269545,  399.99775129),
#           ( 3, 127.17019274, 25.39086092, 127.16947852, 25.39164261,  2.42861071,  5.22304064, 230.89079272,  36.34009196,  495.99839702),
#           ( 4, 127.10870627, 25.36974067, 127.11118225, 25.37227251,  7.70321   , 10.24729259, 162.69753486,  20.08836391,  351.99786012),
#           ( 5, 127.06933551, 25.39638794, 127.07272377, 25.39360369,  9.51773176,  8.76527938, 266.78616076,  19.02260395,  463.9972197 ),
#           ( 6, 127.11485563, 25.36752052, 127.11536111, 25.36788556,  1.95016936,  2.64399698, 111.09994194,  51.53999064,  271.99835059),
#           ( 7, 127.13821991, 25.36530384, 127.13877545, 25.36543783,  2.97294485,  4.99019168, 151.99367028,  28.12566993,  399.99773378),
# ...

# %%
from astropy.table import Table

# %%
Table.read('clump.FIT')
# Out:
# <Table length=95>
# PIDENT        Peak1        ...         Peak               Volume
#                deg         ...      mJy / beam           arcsec2
# int32        float64       ...       float64             float64
# ------ ------------------- ... ------------------- -------------------
#      1    1.2709886637e+02 ...    1.2216888183e+02    3.5199785640e+02
#      2    1.2725506630e+02 ...    2.7652695453e+01    3.9999775129e+02
#      3    1.2717019274e+02 ...    3.6340091959e+01    4.9599839702e+02
#      4    1.2710870627e+02 ...    2.0088363914e+01    3.5199786012e+02
#      5    1.2706933551e+02 ...    1.9022603946e+01    4.6399721970e+02
#      6    1.2711485563e+02 ...    5.1539990636e+01    2.7199835059e+02
#      7    1.2713821991e+02 ...    2.8125669934e+01    3.9999773378e+02
#      8    1.2728093893e+02 ...    1.7578043579e+01    6.5599623749e+02
#      9    1.2720831147e+02 ...    2.9548238556e+01    1.5999904706e+02
# ...
