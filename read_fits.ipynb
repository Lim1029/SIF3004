# %%
from astropy.io import fits

# %%
hdul = fits.open("S2CLS_GOODS-N_NMF_RMS_DR1.FITS")

# %%
hdul.info()
# Out:
# Filename: S2CLS_GOODS-N_NMF_RMS_DR1.FITS
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     580   (631, 631)   float64

# %%
hdul[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                  -64 / array data type
# NAXIS   =                    2 / number of array dimensions
# NAXIS1  =                  631
# NAXIS2  =                  631
# COMMENT   FITS (Flexible Image Transport System) format is defined in 'Astronomy
# COMMENT   and Astrophysics', volume 376, page 359; bibcode: 2001A&A...376..359H
# LBOUND1 =                -1373 / Pixel origin along axis 1
# LBOUND2 =                -1597 / Pixel origin along axis 2
# LBOUND3 =                    1 / Pixel origin along axis 3
# LABEL   = 'Flux Density'       / Label of the primary array
# BUNIT   = 'pW      '           / Units of the primary array
# DATE    = '2015-03-27T11:47:51' / file creation date (YYYY-MM-DDThh:mm:ss UT)
# ORIGIN  = 'Joint Astronomy Centre, Hilo' / Origin of file
# HDUCLAS1= 'NDF     '           / Starlink NDF (hierarchical n-dim format)
# HDUCLAS2= 'DATA    '           / Array component subclass
# ...
